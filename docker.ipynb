# %% [markdown]
# # A short introduction to containerized software
#
# After spending using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    27.2.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.16.2-desktop.1
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-buildx
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.29.2-desktop.2
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.34
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Alpha) (Docker Inc.)
#     Version:  v0.0.15
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.25
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-extension
#   feedback: Provide feedback, right in your terminal! (Docker Inc.)
#     Version:  v1.0.5
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-feedback
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.3.0
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-init
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.13.0
#     Path:     /Users/jansteiger/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 5
#   Running: 1
#   Paused: 0
#   Stopped: 4
#  Images: 14
#  Server Version: 27.2.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 8fc6bcff51318944179630522a095cc9dbf9f353
#  runc version: v1.1.13-0-g58aa920
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: unconfined
#   cgroupns
#  Kernel Version: 6.10.4-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 8
#  Total Memory: 7.655GiB
#  Name: docker-desktop
#  ID: 231ca5f8-2e6c-4a1e-9613-da59f72ed0a6
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/jansteiger/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   127.0.0.0/8
#  Live Restore Enabled: false
#
# WARNING: daemon is not using the default seccomp profile

# %% [markdown]
# ### What is a container?

# %% [markdown]
# A container is a unit for running a process with the specifications of an image

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# We use containers to make processes easier and more reproducible by running under the same conditions

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# A docker image is a specification for the environment to run a process.

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED              STATUS                          PORTS                  NAMES
# 542cdeeab707   hello-world                                                        "/hello"                 55 seconds ago       Exited (0) 54 seconds ago                              pensive_kalam
# 20764d265a05   hello-world                                                        "/hello"                 About a minute ago   Exited (0) About a minute ago                          sharp_germain
# 6133e2de4254   hello-world                                                        "/hello"                 2 minutes ago        Exited (0) 2 minutes ago                               agitated_lehmann
# f3a82ca130d7   hello-world                                                        "/hello"                 3 minutes ago        Exited (0) 3 minutes ago                               eager_raman
# e5181da4d907   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   5 minutes ago        Exited (0) 5 minutes ago                               admiring_cray
# ad605ae292ba   hello-world                                                        "/hello"                 19 minutes ago       Exited (0) 19 minutes ago                              silly_wilbur
# 087d60187568   hello-world                                                        "/hello"                 22 minutes ago       Exited (0) 22 minutes ago                              pedantic_wescoff
# 145e9a39f11b   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago           Exited (137) 2 days ago                                nxf-DwilOsUdXcb7A9BgyQmckFfT
# f4ac38e11483   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago           Exited (137) 2 days ago                                nxf-eSPcyfidSEvvNRK9SQPlgiy4
# d3f47c293a95   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago           Exited (137) 2 days ago                                nxf-1OWEtoJsFH5PQfIRyqeYbKX0
# 0f1d9ab68424   quay.io/biocontainers/wget:1.20.1                                  "/bin/bash -c 'eval …"   3 days ago           Exited (137) 3 days ago                                nxf-R6wL4JfiT6Xcp4Ft1DsEHoQ4
# 81c27ce5e7b4   docker/welcome-to-docker:latest                                    "/docker-entrypoint.…"   4 days ago           Up 4 days                       0.0.0.0:8088->80/tcp   welcome-to-docker

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm 542cdeeab707
# Out:
# 542cdeeab707

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED          STATUS                      PORTS                  NAMES
# 20764d265a05   hello-world                                                        "/hello"                 2 minutes ago    Exited (0) 2 minutes ago                           sharp_germain
# 6133e2de4254   hello-world                                                        "/hello"                 3 minutes ago    Exited (0) 3 minutes ago                           agitated_lehmann
# f3a82ca130d7   hello-world                                                        "/hello"                 4 minutes ago    Exited (0) 4 minutes ago                           eager_raman
# e5181da4d907   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   6 minutes ago    Exited (0) 6 minutes ago                           admiring_cray
# ad605ae292ba   hello-world                                                        "/hello"                 20 minutes ago   Exited (0) 20 minutes ago                          silly_wilbur
# 087d60187568   hello-world                                                        "/hello"                 23 minutes ago   Exited (0) 23 minutes ago                          pedantic_wescoff
# 145e9a39f11b   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-DwilOsUdXcb7A9BgyQmckFfT
# f4ac38e11483   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-eSPcyfidSEvvNRK9SQPlgiy4
# d3f47c293a95   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-1OWEtoJsFH5PQfIRyqeYbKX0
# 0f1d9ab68424   quay.io/biocontainers/wget:1.20.1                                  "/bin/bash -c 'eval …"   3 days ago       Exited (137) 3 days ago                            nxf-R6wL4JfiT6Xcp4Ft1DsEHoQ4
# 81c27ce5e7b4   docker/welcome-to-docker:latest                                    "/docker-entrypoint.…"   4 days ago       Up 4 days                   0.0.0.0:8088->80/tcp   welcome-to-docker

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. Download FastQC
# 2. Download JRE
# 3. Run software

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
# Out:
# 0.12.1--d3caca66b4f3d3b0: Pulling from library/fastqc
#
# 7c3c4e61: Pulling fs layer
# f16d8faf: Pulling fs layer
# 96a0b3ed: Pulling fs layer
# 89cafbe9: Pulling fs layer
# ca8d6a51: Pulling fs layer
# b700ef54: Pulling fs layer
# b700ef54: Pulling fs layer
# e1045197: Pulling fs layer
# 4a5e885d: Pulling fs layer
# 98df307d: Pulling fs layer
# f7ad9b3c: Pulling fs layer
# 81345b94: Pulling fs layer
# c3c4e61: Download complete MB/361MBMBDownloading  25.17MB/361MBDigest: sha256:ac39a0c379226c3b1c3b1c0e59defae369804dbb5b2339344308d1e0b82506ec
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
# community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0

# %%
# run the container and save the results to a new "fastqc_results" directory
# !docker run -v "/Users/jansteiger/Documents/Comp_workflows/day2/test_sheet/fastq":/data -v "/Users/jansteiger/Documents/Comp_workflows/ILIAS_ Docker worksheet/fastqc_results":/output community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0 fastqc /data/SRX19144486_SRR23195516_1.fastq.gz -o /output
# Out:
# application/gzip
# Started analysis of SRX19144486_SRR23195516_1.fastq.gz
# Approx 5% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 10% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 15% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 20% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 25% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 30% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 35% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 40% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 45% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 50% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 55% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 60% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 65% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 70% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 75% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 80% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 85% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 90% complete for SRX19144486_SRR23195516_1.fastq.gz
# Approx 95% complete for SRX19144486_SRR23195516_1.fastq.gz
# Analysis complete for SRX19144486_SRR23195516_1.fastq.gz

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED          STATUS                      PORTS                  NAMES
# de458f2d5e94   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   17 seconds ago   Exited (0) 17 seconds ago                          bold_carson
# d292578f34ad   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   4 minutes ago    Exited (2) 4 minutes ago                           quirky_heisenberg
# f809a5e3b7cb   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   5 minutes ago    Exited (2) 5 minutes ago                           hungry_booth
# dc24d4fb7e96   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   5 minutes ago    Exited (2) 5 minutes ago                           jovial_cray
# 4f9c326cd9f1   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   5 minutes ago    Exited (2) 5 minutes ago                           eloquent_hellman
# ddcb343dca6d   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   8 minutes ago    Exited (0) 8 minutes ago                           naughty_joliot
# f4a9d37b3750   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   13 minutes ago   Exited (0) 13 minutes ago                          reverent_germain
# e5c4d27fd8c9   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   13 minutes ago   Exited (0) 13 minutes ago                          3d3094a0fbff
# 1112b4d2e67a   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   18 minutes ago   Exited (0) 18 minutes ago                          focused_carson
# 3d3094a0fbff   community.wave.seqera.io/library/fastqc:0.12.1--5cfd0f3cb6760c42   "/usr/local/bin/_ent…"   18 minutes ago   Exited (2) 18 minutes ago                          objective_lalande
# 20764d265a05   hello-world                                                        "/hello"                 34 minutes ago   Exited (0) 34 minutes ago                          sharp_germain
# 6133e2de4254   hello-world                                                        "/hello"                 35 minutes ago   Exited (0) 35 minutes ago                          agitated_lehmann
# f3a82ca130d7   hello-world                                                        "/hello"                 36 minutes ago   Exited (0) 36 minutes ago                          eager_raman
# ad605ae292ba   hello-world                                                        "/hello"                 52 minutes ago   Exited (0) 52 minutes ago                          silly_wilbur
# 087d60187568   hello-world                                                        "/hello"                 55 minutes ago   Exited (0) 55 minutes ago                          pedantic_wescoff
# 145e9a39f11b   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-DwilOsUdXcb7A9BgyQmckFfT
# f4ac38e11483   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-eSPcyfidSEvvNRK9SQPlgiy4
# d3f47c293a95   quay.io/biocontainers/trim-galore:0.6.7--hdfd78af_0                "/usr/local/env-exec…"   2 days ago       Exited (137) 2 days ago                            nxf-1OWEtoJsFH5PQfIRyqeYbKX0
# 0f1d9ab68424   quay.io/biocontainers/wget:1.20.1                                  "/bin/bash -c 'eval …"   3 days ago       Exited (137) 3 days ago                            nxf-R6wL4JfiT6Xcp4Ft1DsEHoQ4
# 81c27ce5e7b4   docker/welcome-to-docker:latest                                    "/docker-entrypoint.…"   4 days ago       Up 4 days                   0.0.0.0:8088->80/tcp   welcome-to-docker

# %% [markdown]
# ### Now that you know how to use a docker container, which approach between running everything manually and using docker was easier and which approach will be easier in the future?

# %% [markdown]
# Running everything manually can be easier, especially if you already have most of the software installed and the barrier of entry is lower than for docker, but for more demanding tasks and better reproducibility docker makes many things easier.

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# Already mentioned docker is more reproducible

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# Restults are identical
# FastQC version is identical (0.12.1)

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor
# !cat my_dockerfile
# Out:
# # this is the base image the container is built on. In this case, it is a slim version of the Debian operating system.
# FROM debian:bullseye-slim
#
# # these are the labels that are added to the image. They are metadata that can be used to identify the author of the image.
# LABEL image.author.name "yourname"
# LABEL image.author.email "yourmail"
#
# # !TODO: add the command that is run to install the dependencies for the image. In this case, it should be updating the package list and installing curl and cowsay.
#
#
#
# # !TODO: add an ENV line to set environmental variables. In this case, it should set the PATH variable to /usr/games. Explain in the notebook why this is necessary.

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# RUN updates and installs packages
# ENV adds directory to path

# %%
# build the docker image
# !docker build -t my_image -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.1s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.3s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (7/7) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.31kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => CACHED [2/2] RUN apt-get update &&     apt-get install -y curl cowsay  0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:6c2fea79468618cd910b693daf0bf71f15ef28e2  0.0s
#  => => exporting config sha256:8cb930216b086a1e5926165ab4198c9747c5051e89  0.0s
#  => => exporting attestation manifest sha256:cc9f17aab87030ca65e49069c141  0.0s
#  => => exporting manifest list sha256:64f5d4d7f6a0d8c1e885c801142352327fc  0.0s
#  => => naming to docker.io/library/my_image:latest                         0.0s
#  => => unpacking to docker.io/library/my_image:latest                      0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/x2qbznyiqndsjaeep5vybmqui\docker-desktop://dashboard/build/desktop-linux/desktop-linux/x2qbznyiqndsjaeep5vybmqui]8;;\
#
#  3 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "ENV key=value" should be used instead of legacy "ENV key value" format (line 17)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# make sure that the image has been built
# !docker image ls my_image
# Out:
# REPOSITORY   TAG       IMAGE ID       CREATED         SIZE
# my_image     latest    64f5d4d7f6a0   7 minutes ago   201MB

# %%
# run the docker file 
# !docker run my_image cowsay "Docker is working"
# Out:
#  ___________________
# < Docker is working >
#  -------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image

# %%
# build the image
# !docker build -t salmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
# [+] Building 0.9s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 0.9s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
# [+] Building 1.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c 0B / 31.43MB  0.2s
# [+] Building 1.3s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c 0B / 31.43MB  0.3s
# [+] Building 1.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 1.05MB / 31.43MB  0.5s
# [+] Building 1.6s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 1.05MB / 31.43MB  0.6s
# [+] Building 1.6s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 1.05MB / 31.43MB  0.6s
# [+] Building 1.7s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 1.05MB / 31.43MB  0.8s
# [+] Building 1.7s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 2.10MB / 31.43MB  0.8s
# [+] Building 1.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 2.10MB / 31.43MB  0.9s
# [+] Building 1.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 2.10MB / 31.43MB  0.9s
# [+] Building 2.0s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 2.10MB / 31.43MB  1.1s
# [+] Building 2.0s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 3.15MB / 31.43MB  1.1s
# [+] Building 2.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 3.15MB / 31.43MB  1.2s
# [+] Building 2.3s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 3.15MB / 31.43MB  1.4s
# [+] Building 2.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 4.19MB / 31.43MB  1.5s
# [+] Building 2.6s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 4.19MB / 31.43MB  1.7s
# [+] Building 2.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 5.24MB / 31.43MB  1.8s
# [+] Building 2.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 5.24MB / 31.43MB  2.0s
# [+] Building 2.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 5.24MB / 31.43MB  2.0s
# [+] Building 3.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 5.24MB / 31.43MB  2.1s
# [+] Building 3.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 6.29MB / 31.43MB  2.1s
# [+] Building 3.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 6.29MB / 31.43MB  2.3s
# [+] Building 3.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 6.29MB / 31.43MB  2.3s
# [+] Building 3.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 7.34MB / 31.43MB  2.4s
# [+] Building 3.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 7.34MB / 31.43MB  2.6s
# [+] Building 3.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 7.34MB / 31.43MB  2.6s
# [+] Building 3.7s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 8.39MB / 31.43MB  2.7s
# [+] Building 3.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 8.39MB / 31.43MB  2.9s
# [+] Building 3.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 8.39MB / 31.43MB  2.9s
# [+] Building 4.0s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 9.44MB / 31.43MB  3.0s
# [+] Building 4.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41 9.44MB / 31.43MB  3.2s
# [+] Building 4.3s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 10.49MB / 31.43MB  3.3s
# [+] Building 4.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 10.49MB / 31.43MB  3.5s
# [+] Building 4.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 10.49MB / 31.43MB  3.5s
# [+] Building 4.6s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 11.53MB / 31.43MB  3.6s
# [+] Building 4.7s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 12.58MB / 31.43MB  3.8s
# [+] Building 4.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 12.58MB / 31.43MB  3.9s
# [+] Building 5.0s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 13.63MB / 31.43MB  4.1s
# [+] Building 5.0s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 13.63MB / 31.43MB  4.1s
# [+] Building 5.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 13.63MB / 31.43MB  4.2s
# [+] Building 5.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 13.63MB / 31.43MB  4.2s
# [+] Building 5.3s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 14.68MB / 31.43MB  4.4s
# [+] Building 5.3s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 14.68MB / 31.43MB  4.4s
# [+] Building 5.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 15.73MB / 31.43MB  4.5s
# [+] Building 5.6s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 15.73MB / 31.43MB  4.7s
# [+] Building 5.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  4.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 16.78MB / 31.43MB  4.8s
# [+] Building 5.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 16.78MB / 31.43MB  5.0s
# [+] Building 5.9s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 16.78MB / 31.43MB  5.0s
# [+] Building 6.1s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 17.83MB / 31.43MB  5.1s
# [+] Building 6.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 17.83MB / 31.43MB  5.3s
# [+] Building 6.2s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 17.83MB / 31.43MB  5.3s
# [+] Building 6.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 18.87MB / 31.43MB  5.4s
# [+] Building 6.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 18.87MB / 31.43MB  5.6s
# [+] Building 6.5s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 19.92MB / 31.43MB  5.6s
# [+] Building 6.7s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 19.92MB / 31.43MB  5.7s
# [+] Building 6.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  5.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 19.92MB / 31.43MB  5.9s
# [+] Building 6.8s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# ...
#  => => exporting layers                                                    4.3s
# [+] Building 57.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     4.5s
#  => => exporting layers                                                    4.5s
# [+] Building 57.1s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     4.6s
#  => => exporting layers                                                    4.6s
# [+] Building 57.2s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     4.8s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
# [+] Building 57.4s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     4.9s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.1s
# [+] Building 57.6s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.1s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.3s
# [+] Building 57.7s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.2s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.4s
# [+] Building 57.9s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.4s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.6s
# [+] Building 58.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.5s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.7s
# [+] Building 58.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.6s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.8s
# [+] Building 58.2s (7/7) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 821B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  9.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:610b4c7ad241  0.0s
#  => => sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae4 31.43MB / 31.43MB  8.6s
#  => => extracting sha256:6dce3b49cfe6dc4b4e0198412bb0578215c86dae41303c47  0.4s
#  => [2/3] RUN apt-get update && apt-get install -y curl tar               26.4s
#  => [3/3] RUN curl -L -o salmon.tar.gz https://github.com/COMBINE-lab/sa  16.1s
#  => exporting to image                                                     5.6s
#  => => exporting layers                                                    4.8s
#  => => exporting manifest sha256:919082bb69e672949a57443a9f0bfc2e02e54163  0.0s
#  => => exporting config sha256:421735319ff1bad807249f10b7b9d4b98d0c06b864  0.0s
#  => => exporting attestation manifest sha256:de3194a2a0a8389fcfad333c3fee  0.0s
#  => => exporting manifest list sha256:58fb57731c736c4a42fe163415a506a3433  0.0s
#  => => naming to docker.io/library/salmon:latest                           0.0s
#  => => unpacking to docker.io/library/salmon:latest                        0.8s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/mi2ocf5o18h4bj7e486w42kr1\docker-desktop://dashboard/build/desktop-linux/desktop-linux/mi2ocf5o18h4bj7e486w42kr1]8;;\
#
#  1 warning found (use docker --debug to expand):
#  - FromPlatformFlagConstDisallowed: FROM --platform flag should not use constant value "linux/amd64" (line 1)
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# run the docker image to give out the version of salmon
# !docker run salmon salmon --version
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %% [markdown]
# BioContainers is a community-driven project that provides the infrastructure and basic guidelines to create, manage and distribute bioinformatics packages (e.g conda) and containers (e.g docker, singularity).

# %%
# !docker pull combinelab/salmon
# !docker run combinelab/salmon salmon --version
# Out:
# Using default tag: latest
# latest: Pulling from combinelab/salmon
# Digest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370
# Status: Image is up to date for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview combinelab/salmon
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# salmon 1.10.3
