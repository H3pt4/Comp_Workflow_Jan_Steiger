# %% [markdown]
# ## Great, now that we discussed a little let's continue

# %% [markdown]
# Given that the current approach utilized by the authors lacks reproducibility, we will explore an alternative method by leveraging nf-core pipelines for data analysis.
#
# Please explain, how we will achieve reproducibility for the course  with this approach.

# %% [markdown]
# We will use a pipeline to streamline the process, using same packages versions etc., so that the process from input to output leaves little room for variance.

# %% [markdown]
# You have successfully downloaded 2 of the fastq files we will use in our study.
#
# What is the next step if we want to first have a count table and check the quality of our fastq files? What is the pipeline called to do so?

# %% [markdown]
# nf-core/rnaseq

# %% [markdown]
# Analyze the 2 files using an nf-core pipeline.
#
# What does this pipeline do?
#
# Which are the main tools that will be used in the pipeline?

# %%
sheet = pd.read_csv('test_sheet/samplesheet/samplesheet.csv')
sheet = sheet[['sample', 'fastq_1', 'fastq_2']]
sheet['strandedness'] = ['auto', 'auto']
sheet.to_csv('samplesheet_rna.csv', header=True, index=False)

# %%
# post here the command you used to run nf-core/rnaseq
# !nextflow run nf-core/rnaseq -profile test,docker --input samplesheet_rna.csv --outdir rna_seq --genome GRCm38 --aligner hisat2 --max_cpus 8 --max_memory 16GB
# Out:
# Nextflow 24.04.4 is available - Please consider updating your version to it
# N E X T F L O W  ~  version 23.10.0
# Launching `https://github.com/nf-core/rnaseq` [compassionate_lamarr] DSL2 - revision: 4053b2ec17 [master]
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/rnaseq v3.15.1-g4053b2e
# ------------------------------------------------------
# Core Nextflow options
#   revision                  : master
#   runName                   : compassionate_lamarr
#   containerEngine           : docker
#   launchDir                 : /Users/jansteiger/Documents/Comp_workflows/day2
# ...

# %% [markdown]
# Performs quality control, trimming, alignment

# %% [markdown]
# As all other nf-core pipelines, the chosen pipeline takes in a samplesheet as input.
#
# Use Python and pandas to create the samplesheet for your 2 samples. Feel free to make use of the table you created earlier today.
#
# Choose your sample names wisely, they must be the connection of the results to the metadata. If you can't find the sample in the metadata later, the analysis was useless.

# %%
# post here the command you used to run nf-core/rnaseq
# !nextflow run nf-core/rnaseq -profile test,docker --input samplesheet_rna.csv --outdir rna_seq --genome GRCm38 --aligner hisat2 --max_cpus 8 --max_memory 16GB

# %% [markdown]
# Explain all the parameters you set and why you set them in this way.

# %% [markdown]
# -profile:
# --input: The samplesheet containing information to the fastq files
# --outdir: Save results to this folder
# --genome: The reference genome for mapping
# --aligner: Specify usage of aligner, default being salmon
# --max_cpus/memory: Specify CPU/memory usage

# %% [markdown]
# ## Browsing the results

# %% [markdown]
# ### How did the pipeline perform?

# %% [markdown]
# Good, took some time

# %% [markdown]
# Explain the quality control steps. Are you happy with the quality and why. If not, why not.
# Please give additional information on :
# - ribosomal rRNA
# - Duplication
# - GC content
#
# What are the possible steps that could lead to poorer results?

# %% [markdown]
# Quality control:
# 1. Strandedness prediction
# 2. Check amount of exonic reads
# 3. look at splice junctions
# 4. calculate inner distance for two paired end reads
# 5. Detect splice site saturation
# 6. Assess read duplications
# 7. Evaluate RNA integrity
# 8. Assess mapping and coverage
# 9. Check duplication rate vs expression
# 10. Estimate number of redundant reads
# 11. Step 2 again

# %% [markdown]
# Generally good quality reads
#
# rRNA very low, with some exceptions at around 1% and outliers are SNI_Sal 2 and SNI_Sal 4 (more than 20%, high contamination).
#
# Duplication generally fine, SNI_Sal 2/4 might be too high
#
# GC content around 50%
#
# Problems: technical problems, contamination

# %% [markdown]
# Would you exclude any samples? If yes, which and why?

# %% [markdown]
# Sham-oxy 1 maps has significantly less reads (thus also lower coverage), maybe exclude
#
# SNI-Sal 2 and 4 have high contamination, maybe combined with excessive duplication, also seem to skew PCA, maybe exclude

# %% [markdown]
# ### What would you now do to continue the experiment? What are the scientists trying to figure out? Which packages on R or python would you use?

# %% [markdown]
# I would look at the differentially expressed genes between to subgroups (now we have only two samples but generally...). This can be accomplished e.g. through the abundence analysis pipeline. The expression levels can be visualized (with SD within the group, use seaborn or matplotlib) and compared to the expression levels of other groups. With this analysis, we can see how the different conditions and phenotypes affect expression levels.
